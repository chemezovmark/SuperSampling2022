# %%
import numpy as np

from model import resolve_single
from model.common import psnr, ssim
from model.edsr import edsr

from utils import load_image, plot

#подключение модели и функций

# %%
model = edsr(scale=4, num_res_blocks=16)
model.load_weights('weights/edsr-16-x4/weights.h5')

#инициализация модели и подключение весов

# %%
model.summary()

#сведения о модели
# Out:
# Model: "edsr"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, None, None, 6 1792        lambda[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 6 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 6 36928       conv2d_1[0][0]
# ...

# %%
lr1 = load_image('demo/KAPIBARA_1.png')
lr2 = load_image('demo/SPB_1.png')
lr3 = load_image('demo/PUSHKIN_1.png')
sr1 = resolve_single(model, lr1)
sr2 = resolve_single(model, lr2)
sr3 = resolve_single(model, lr3)

hr1 = load_image('demo/KAPIBARA_4.png')
hr2 = load_image('demo/SPB_4.png')
hr3 = load_image('demo/PUSHKIN_4.png')

#Загрузка и обработка изображений

# %%
plot(lr1, sr1, hr1)
plot(lr2, sr2, hr2)
plot(lr3, sr3, hr3)

#Отображаем маленькое и восстановленное и большое изображения
